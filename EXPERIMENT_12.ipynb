# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_/blob/main/EXPERIMENT_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Restaurant Menu Grammar

# %%
grammar = {"S": ["dish", "drink"]}

print("FIRST(S):", set(grammar["S"]))
print("FOLLOW(S): {'$'}")
# Out:
# FIRST(S): {'drink', 'dish'}
# FOLLOW(S): {'$'}

# %% [markdown]
# b) Car Manufacturing Rules

# %%
grammar = {"S": ["engine", "wheel"]}

print("FIRST(S):", set(grammar["S"]))
print("FOLLOW(S): {'$'}")
# Out:
# FIRST(S): {'wheel', 'engine'}
# FOLLOW(S): {'$'}
