# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_/blob/main/EXPERIMENT_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Customer Feedback File

# %%
text = input("Enter Customer Feedback:\n")

print("Lines:", len(text.split("\n")))
print("Words:", len(text.split()))
print("Characters:", len(text))
# Out:
# Enter Customer Feedback:
# better than last time
# Lines: 1
# Words: 4
# Characters: 21

# %% [markdown]
# b) Coding Assignment File

# %%
text = input("Enter Coding Assignment Text:\n")

print("Lines:", len(text.split("\n")))
print("Words:", len(text.split()))
print("Characters:", len(text))
# Out:
# Enter Coding Assignment Text:
# staff was friendly
# Lines: 1
# Words: 3
# Characters: 18
