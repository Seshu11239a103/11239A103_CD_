# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_/blob/main/EXPERIMENT_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ops = {"+", "-", "*", "/", "=", "==", "!=", ">", "<", ">=", "<="}

expr = input("Enter expression: ").split()

for i in expr:
    print(i, "-> Operator" if i in ops else "-> Not Operator")
# Out:
# Enter expression: -
# - -> Operator
